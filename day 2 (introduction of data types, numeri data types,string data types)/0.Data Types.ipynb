# %% [markdown]
# <h1><strong>Data Types</strong></h1>
# <pre>       what we will learn here
#             1) defination
#             2) Classification of Data Types
#             3) type() function
#             4) mutuable data types and immutuable datatypes
#             5) conversion of one data type to other data types
#
#
#
# </pre>

# %% [markdown]
# <code style="background:Gold;color:black">Data :-</code>
# <pre>            a piece of information

# %% [markdown]
# <code style="background:Gold;color:black">Data Types:-</code>
# <pre>   Data types define the type of data that a variable can hold.</pre>

# %%
a=10
name="vikas"
print(a)
print(name)
# Out:
# 10
# vikas

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# <code style="background:aqua;color:black">Classification of Data Types:-</code>

# %% [markdown]
# ![types.jpg](attachment:types.jpg)

# %% [markdown]
# <pre>
#
#
#
# </pre>
